# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import os


# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
        
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
               
# Print the city count to confirm sufficient count
len(cities)
print(len(cities))
cities_df=pd.DataFrame({"City":cities})
cities_df.head()
# Out:
# 612
#            City
# 0    nikolskoye
# 1         wajid
# 2         sabha
# 3          emba
# 4  saint-joseph

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).
#
# > **HINT:** The OpenWeatherMap API only allows 60 calls per minute under their free plan. Try using `time.sleep(60)` after each set of 50 cities to avoid API errors due to large calls.

# %%
# Save config information

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "units=metric"
query_url = f"{url}appid={weather_api_key}&units={units}&q="

Cloudiness=[]
Country=[]
Date=[]
Humidity=[]
Lat=[]
Lng=[]
Max_temp=[]
Wind_speed=[]

count = 0
set_group = 1

city_name=[]


# print beginning of retrived data
print("Beginning Data Retrieval")
print("------------------------")

# use a for loop to iterate through cities  
for city in cities:
    
    
    try:
        if count <= 49:
        
            count +=1
            
        
            response = requests.get(query_url + city).json()
            city_name.append(city)
        
            Cloudiness.append(response["clouds"]["all"])
       
            Country.append(response["sys"]["country"])
            Date.append(response["dt"])
            Humidity.append(response["main"]["humidity"])
            Lat.append(response["coord"]["lat"])
            Lng.append(response["coord"]["lon"])
            Max_temp.append(response ["main"]["temp_max"])
            Wind_speed.append(response["wind"]["speed"])
            print(f"Processig Record {count} of Set {set_group} | {city}")  
        
          
        else:
            count =0
            set_group += 1
            
            city_name.append(city)
            time.sleep(60)
        
       
        
    except Exception: 
        print("City not found.Skipping...")
    
        
print("--------------------------------------------------------")                      
print("----------------End of Data Retrieval-------------------")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processig Record 1 of Set 1 | nikolskoye
# Processig Record 2 of Set 1 | wajid
# Processig Record 3 of Set 1 | sabha
# Processig Record 4 of Set 1 | emba
# Processig Record 5 of Set 1 | saint-joseph
# Processig Record 6 of Set 1 | la ronge
# Processig Record 7 of Set 1 | ponta do sol
# Processig Record 8 of Set 1 | victoria
# Processig Record 9 of Set 1 | bengkulu
# Processig Record 10 of Set 1 | bambous virieux
# Processig Record 11 of Set 1 | butaritari
# Processig Record 12 of Set 1 | vaini
# Processig Record 13 of Set 1 | tikrit
# Processig Record 14 of Set 1 | flin flon
# City not found.Skipping...
# Processig Record 16 of Set 1 | ribeira grande
# Processig Record 17 of Set 1 | albany
# Processig Record 18 of Set 1 | esperance
# Processig Record 19 of Set 1 | jambi
# Processig Record 20 of Set 1 | burns lake
# Processig Record 21 of Set 1 | cape town
# Processig Record 22 of Set 1 | broome
# Processig Record 23 of Set 1 | luderitz
# City not found.Skipping...
# Processig Record 25 of Set 1 | klaksvik
# Processig Record 26 of Set 1 | carnarvon
# Processig Record 27 of Set 1 | ushuaia
# Processig Record 28 of Set 1 | tuktoyaktuk
# City not found.Skipping...
# Processig Record 30 of Set 1 | rock sound
# Processig Record 31 of Set 1 | yellowknife
# Processig Record 32 of Set 1 | hilo
# Processig Record 33 of Set 1 | panguna
# Processig Record 34 of Set 1 | busselton
# Processig Record 35 of Set 1 | atuona
# Processig Record 36 of Set 1 | monrovia
# Processig Record 37 of Set 1 | jamestown
# Processig Record 38 of Set 1 | dunedin
# Processig Record 39 of Set 1 | lompoc
# City not found.Skipping...
# Processig Record 41 of Set 1 | saint george
# Processig Record 42 of Set 1 | port elizabeth
# Processig Record 43 of Set 1 | paamiut
# Processig Record 44 of Set 1 | carlyle
# Processig Record 45 of Set 1 | slave lake
# Processig Record 46 of Set 1 | rikitea
# Processig Record 47 of Set 1 | bethel
# Processig Record 48 of Set 1 | punta arenas
# Processig Record 49 of Set 1 | los llanos de aridane
# Processig Record 50 of Set 1 | mataura
# Processig Record 1 of Set 2 | fortuna
# Processig Record 2 of Set 2 | avarua
# Processig Record 3 of Set 2 | haines junction
# Processig Record 4 of Set 2 | kaitangata
# Processig Record 5 of Set 2 | arraial do cabo
# Processig Record 6 of Set 2 | lavrentiya
# Processig Record 7 of Set 2 | bintulu
# City not found.Skipping...
# City not found.Skipping...
# Processig Record 10 of Set 2 | bentiu
# Processig Record 11 of Set 2 | beringovskiy
# Processig Record 12 of Set 2 | irpa irpa
# Processig Record 13 of Set 2 | djambala
# Processig Record 14 of Set 2 | grafton
# Processig Record 15 of Set 2 | petropavlovsk-kamchatskiy
# Processig Record 16 of Set 2 | coquimbo
# Processig Record 17 of Set 2 | atoka
# Processig Record 18 of Set 2 | hithadhoo
# Processig Record 19 of Set 2 | georgetown
# Processig Record 20 of Set 2 | barcelos
# Processig Record 21 of Set 2 | padre bernardo
# Processig Record 22 of Set 2 | mar del plata
# Processig Record 23 of Set 2 | acapulco
# Processig Record 24 of Set 2 | port hardy
# Processig Record 25 of Set 2 | ternate
# Processig Record 26 of Set 2 | labuhan
# Processig Record 27 of Set 2 | qaanaaq
# Processig Record 28 of Set 2 | alofi
# City not found.Skipping...
# Processig Record 30 of Set 2 | new norfolk
# Processig Record 31 of Set 2 | bac lieu
# Processig Record 32 of Set 2 | presidente dutra
# Processig Record 33 of Set 2 | airai
# Processig Record 34 of Set 2 | oxford
# Processig Record 35 of Set 2 | tokur
# Processig Record 36 of Set 2 | portland
# Processig Record 37 of Set 2 | bredasdorp
# Processig Record 38 of Set 2 | grand gaube
# Processig Record 39 of Set 2 | gizo
# Processig Record 40 of Set 2 | sijunjung
# Processig Record 41 of Set 2 | port lincoln
# Processig Record 42 of Set 2 | castro
# Processig Record 43 of Set 2 | chardara
# Processig Record 44 of Set 2 | faanui
# Processig Record 45 of Set 2 | russell
# Processig Record 46 of Set 2 | ngama
# Processig Record 47 of Set 2 | bhatkal
# Processig Record 48 of Set 2 | walcz
# Processig Record 49 of Set 2 | port blair
# Processig Record 50 of Set 2 | hermanus
# Processig Record 1 of Set 3 | kholm
# Processig Record 2 of Set 3 | linfen
# Processig Record 3 of Set 3 | te anau
# Processig Record 4 of Set 3 | hobart
# Processig Record 5 of Set 3 | ilulissat
# Processig Record 6 of Set 3 | saint anthony
# Processig Record 7 of Set 3 | mahina
# Processig Record 8 of Set 3 | fowa
# Processig Record 9 of Set 3 | saint-marc
# City not found.Skipping...
# Processig Record 11 of Set 3 | pampierstad
# Processig Record 12 of Set 3 | vardo
# Processig Record 13 of Set 3 | barrow
# Processig Record 14 of Set 3 | minab
# City not found.Skipping...
# Processig Record 16 of Set 3 | zapresic
# Processig Record 17 of Set 3 | yankton
# Processig Record 18 of Set 3 | jiaocheng
# Processig Record 19 of Set 3 | huarmey
# Processig Record 20 of Set 3 | vila franca do campo
# Processig Record 21 of Set 3 | north platte
# Processig Record 22 of Set 3 | nemuro
# Processig Record 23 of Set 3 | tasiilaq
# Processig Record 24 of Set 3 | olafsvik
# Processig Record 25 of Set 3 | aripuana
# Processig Record 26 of Set 3 | deputatskiy
# Processig Record 27 of Set 3 | bhum
# Processig Record 28 of Set 3 | kavaratti
# Processig Record 29 of Set 3 | havre-saint-pierre
# Processig Record 30 of Set 3 | tombouctou
# Processig Record 31 of Set 3 | ardakan
# Processig Record 32 of Set 3 | tuy hoa
# Processig Record 33 of Set 3 | auki
# Processig Record 34 of Set 3 | karachi
# Processig Record 35 of Set 3 | batagay
# Processig Record 36 of Set 3 | san quintin
# Processig Record 37 of Set 3 | severo-kurilsk
# Processig Record 38 of Set 3 | norman wells
# Processig Record 39 of Set 3 | port alfred
# Processig Record 40 of Set 3 | kodiak
# Processig Record 41 of Set 3 | puerto ayora
# Processig Record 42 of Set 3 | vestmannaeyjar
# Processig Record 43 of Set 3 | qaqortoq
# Processig Record 44 of Set 3 | eyl
# Processig Record 45 of Set 3 | rassvet
# Processig Record 46 of Set 3 | kirakira
# Processig Record 47 of Set 3 | sinnamary
# Processig Record 48 of Set 3 | vostok
# Processig Record 49 of Set 3 | aykhal
# Processig Record 50 of Set 3 | baracoa
# Processig Record 1 of Set 4 | west hartford
# Processig Record 2 of Set 4 | kapaa
# Processig Record 3 of Set 4 | pevek
# Processig Record 4 of Set 4 | hambantota
# Processig Record 5 of Set 4 | manyana
# Processig Record 6 of Set 4 | copiapo
# Processig Record 7 of Set 4 | winneba
# Processig Record 8 of Set 4 | magugu
# Processig Record 9 of Set 4 | lagoa
# Processig Record 10 of Set 4 | tucuma
# Processig Record 11 of Set 4 | kasongo-lunda
# Processig Record 12 of Set 4 | koslan
# Processig Record 13 of Set 4 | kyra
# Processig Record 14 of Set 4 | corinto
# Processig Record 15 of Set 4 | bluff
# Processig Record 16 of Set 4 | hasaki
# Processig Record 17 of Set 4 | kosa
# Processig Record 18 of Set 4 | sibu
# Processig Record 19 of Set 4 | sabathu
# Processig Record 20 of Set 4 | puerto escondido
# City not found.Skipping...
# Processig Record 22 of Set 4 | havoysund
# Processig Record 23 of Set 4 | tuatapere
# Processig Record 24 of Set 4 | ajdabiya
# Processig Record 25 of Set 4 | lae
# Processig Record 26 of Set 4 | sawakin
# Processig Record 27 of Set 4 | kawalu
# Processig Record 28 of Set 4 | cabedelo
# Processig Record 29 of Set 4 | niamey
# Processig Record 30 of Set 4 | fengzhen
# Processig Record 31 of Set 4 | cidreira
# City not found.Skipping...
# Processig Record 33 of Set 4 | leningradskiy
# Processig Record 34 of Set 4 | monticello
# Processig Record 35 of Set 4 | yilan
# Processig Record 36 of Set 4 | kyren
# Processig Record 37 of Set 4 | lazaro cardenas
# Processig Record 38 of Set 4 | iqaluit
# Processig Record 39 of Set 4 | sovetskoye
# Processig Record 40 of Set 4 | namibe
# Processig Record 41 of Set 4 | avera
# Processig Record 42 of Set 4 | antofagasta
# Processig Record 43 of Set 4 | big spring
# Processig Record 44 of Set 4 | umm kaddadah
# Processig Record 45 of Set 4 | padang
# City not found.Skipping...
# Processig Record 47 of Set 4 | volchikha
# Processig Record 48 of Set 4 | chuy
# Processig Record 49 of Set 4 | almaznyy
# Processig Record 50 of Set 4 | moranbah
# City not found.Skipping...
# City not found.Skipping...
# Processig Record 3 of Set 5 | porto novo
# Processig Record 4 of Set 5 | srednekolymsk
# Processig Record 5 of Set 5 | saint-francois
# Processig Record 6 of Set 5 | horana
# Processig Record 7 of Set 5 | terrace bay
# Processig Record 8 of Set 5 | kaputa
# Processig Record 9 of Set 5 | tenkodogo
# Processig Record 10 of Set 5 | moose factory
# Processig Record 11 of Set 5 | sechura
# Processig Record 12 of Set 5 | gotsu
# Processig Record 13 of Set 5 | san cristobal
# Processig Record 14 of Set 5 | myaundzha
# Processig Record 15 of Set 5 | morant bay
# City not found.Skipping...
# Processig Record 17 of Set 5 | lingao
# Processig Record 18 of Set 5 | kroya
# City not found.Skipping...
# Processig Record 20 of Set 5 | miri
# Processig Record 21 of Set 5 | palmer
# City not found.Skipping...
# Processig Record 23 of Set 5 | karasburg
# Processig Record 24 of Set 5 | poum
# Processig Record 25 of Set 5 | tapejara
# Processig Record 26 of Set 5 | hofn
# Processig Record 27 of Set 5 | ubaitaba
# Processig Record 28 of Set 5 | devils lake
# Processig Record 29 of Set 5 | okmulgee
# Processig Record 30 of Set 5 | clyde river
# Processig Record 31 of Set 5 | mihara
# Processig Record 32 of Set 5 | talnakh
# Processig Record 33 of Set 5 | skjervoy
# City not found.Skipping...
# Processig Record 35 of Set 5 | ngunguru
# Processig Record 36 of Set 5 | shahr-e kord
# Processig Record 37 of Set 5 | rabaul
# Processig Record 38 of Set 5 | aklavik
# Processig Record 39 of Set 5 | longyearbyen
# Processig Record 40 of Set 5 | tshikapa
# Processig Record 41 of Set 5 | general roca
# Processig Record 42 of Set 5 | loudi
# Processig Record 43 of Set 5 | oktyabrskiy
# Processig Record 44 of Set 5 | sogne
# Processig Record 45 of Set 5 | kijang
# Processig Record 46 of Set 5 | vila velha
# Processig Record 47 of Set 5 | kelo
# Processig Record 48 of Set 5 | launceston
# Processig Record 49 of Set 5 | lubango
# Processig Record 50 of Set 5 | harper
# Processig Record 1 of Set 6 | high prairie
# Processig Record 2 of Set 6 | cherskiy
# Processig Record 3 of Set 6 | chaman
# Processig Record 4 of Set 6 | guerrero negro
# Processig Record 5 of Set 6 | pedra
# Processig Record 6 of Set 6 | nouadhibou
# Processig Record 7 of Set 6 | khatanga
# Processig Record 8 of Set 6 | fort nelson
# Processig Record 9 of Set 6 | newton
# Processig Record 10 of Set 6 | constitucion
# Processig Record 11 of Set 6 | souillac
# Processig Record 12 of Set 6 | weinan
# Processig Record 13 of Set 6 | gwanda
# Processig Record 14 of Set 6 | nanortalik
# City not found.Skipping...
# Processig Record 16 of Set 6 | aykino
# Processig Record 17 of Set 6 | sibolga
# City not found.Skipping...
# City not found.Skipping...
# Processig Record 20 of Set 6 | udala
# Processig Record 21 of Set 6 | kieta
# Processig Record 22 of Set 6 | dikson
# Processig Record 23 of Set 6 | gat
# Processig Record 24 of Set 6 | verkhnevilyuysk
# Processig Record 25 of Set 6 | kruisfontein
# Processig Record 26 of Set 6 | east london
# Processig Record 27 of Set 6 | yar-sale
# Processig Record 28 of Set 6 | oranjemund
# Processig Record 29 of Set 6 | lebu
# Processig Record 30 of Set 6 | hamilton
# Processig Record 31 of Set 6 | maicao
# Processig Record 32 of Set 6 | tomatlan
# Processig Record 33 of Set 6 | sakakah
# City not found.Skipping...
# Processig Record 35 of Set 6 | tiksi
# Processig Record 36 of Set 6 | diu
# Processig Record 37 of Set 6 | katsuura
# Processig Record 38 of Set 6 | tripoli
# Processig Record 39 of Set 6 | mao
# Processig Record 40 of Set 6 | kampot
# Processig Record 41 of Set 6 | provideniya
# Processig Record 42 of Set 6 | clarksburg
# Processig Record 43 of Set 6 | perdoes
# Processig Record 44 of Set 6 | totoro
# Processig Record 45 of Set 6 | becerril
# Processig Record 46 of Set 6 | nuuk
# Processig Record 47 of Set 6 | upernavik
# City not found.Skipping...
# Processig Record 49 of Set 6 | batie
# Processig Record 50 of Set 6 | coahuayana
# Processig Record 1 of Set 7 | richards bay
# Processig Record 2 of Set 7 | ostrovnoy
# City not found.Skipping...
# Processig Record 4 of Set 7 | coihaique
# City not found.Skipping...
# Processig Record 6 of Set 7 | rauma
# Processig Record 7 of Set 7 | maniitsoq
# Processig Record 8 of Set 7 | alice springs
# Processig Record 9 of Set 7 | ewa beach
# Processig Record 10 of Set 7 | nantucket
# Processig Record 11 of Set 7 | sur
# Processig Record 12 of Set 7 | poya
# Processig Record 13 of Set 7 | vysotsk
# Processig Record 14 of Set 7 | cabo san lucas
# Processig Record 15 of Set 7 | ronne
# Processig Record 16 of Set 7 | lorengau
# Processig Record 17 of Set 7 | candido mendes
# Processig Record 18 of Set 7 | touros
# Processig Record 19 of Set 7 | hami
# Processig Record 20 of Set 7 | balkanabat
# Processig Record 21 of Set 7 | hit
# Processig Record 22 of Set 7 | funtua
# Processig Record 23 of Set 7 | kadrina
# Processig Record 24 of Set 7 | vao
# Processig Record 25 of Set 7 | praia
# Processig Record 26 of Set 7 | hanko
# Processig Record 27 of Set 7 | saskylakh
# Processig Record 28 of Set 7 | kedrovyy
# Processig Record 29 of Set 7 | sistranda
# Processig Record 30 of Set 7 | barra do garcas
# Processig Record 31 of Set 7 | salalah
# Processig Record 32 of Set 7 | sitka
# Processig Record 33 of Set 7 | alpena
# City not found.Skipping...
# Processig Record 35 of Set 7 | codrington
# Processig Record 36 of Set 7 | ulladulla
# Processig Record 37 of Set 7 | asau
# Processig Record 38 of Set 7 | bonnyville
# Processig Record 39 of Set 7 | chabahar
# Processig Record 40 of Set 7 | lerwick
# City not found.Skipping...
# Processig Record 42 of Set 7 | nizhnevartovsk
# Processig Record 43 of Set 7 | mountain home
# Processig Record 44 of Set 7 | lasa
# Processig Record 45 of Set 7 | altay
# Processig Record 46 of Set 7 | khani
# Processig Record 47 of Set 7 | sabang
# Processig Record 48 of Set 7 | aksu
# Processig Record 49 of Set 7 | karasjok
# City not found.Skipping...
# Processig Record 1 of Set 8 | lincoln
# Processig Record 2 of Set 8 | kalabo
# Processig Record 3 of Set 8 | diamantino
# Processig Record 4 of Set 8 | blagoyevo
# Processig Record 5 of Set 8 | mount isa
# Processig Record 6 of Set 8 | cockburn town
# Processig Record 7 of Set 8 | rundu
# Processig Record 8 of Set 8 | katherine
# City not found.Skipping...
# Processig Record 10 of Set 8 | romano di lombardia
# Processig Record 11 of Set 8 | sangar
# Processig Record 12 of Set 8 | shihezi
# Processig Record 13 of Set 8 | khandbari
# Processig Record 14 of Set 8 | sydney
# Processig Record 15 of Set 8 | mahibadhoo
# Processig Record 16 of Set 8 | ocos
# Processig Record 17 of Set 8 | khandyga
# Processig Record 18 of Set 8 | durban
# Processig Record 19 of Set 8 | namikupa
# Processig Record 20 of Set 8 | san patricio
# Processig Record 21 of Set 8 | honningsvag
# Processig Record 22 of Set 8 | waddan
# Processig Record 23 of Set 8 | halifax
# Processig Record 24 of Set 8 | kuching
# Processig Record 25 of Set 8 | nabire
# Processig Record 26 of Set 8 | fukue
# Processig Record 27 of Set 8 | aksha
# Processig Record 28 of Set 8 | ust-tsilma
# Processig Record 29 of Set 8 | medea
# Processig Record 30 of Set 8 | flinders
# Processig Record 31 of Set 8 | ariquemes
# Processig Record 32 of Set 8 | beloha
# Processig Record 33 of Set 8 | butterworth
# Processig Record 34 of Set 8 | zwettl
# City not found.Skipping...
# Processig Record 36 of Set 8 | teya
# Processig Record 37 of Set 8 | perpignan
# City not found.Skipping...
# Processig Record 39 of Set 8 | bambanglipuro
# Processig Record 40 of Set 8 | staryy nadym
# Processig Record 41 of Set 8 | yulara
# Processig Record 42 of Set 8 | chokurdakh
# Processig Record 43 of Set 8 | morwell
# Processig Record 44 of Set 8 | bubaque
# Processig Record 45 of Set 8 | trzebinia
# Processig Record 46 of Set 8 | jutai
# Processig Record 47 of Set 8 | bar harbor
# Processig Record 48 of Set 8 | ponta delgada
# City not found.Skipping...
# Processig Record 50 of Set 8 | mnogovershinnyy
# Processig Record 1 of Set 9 | naron
# Processig Record 2 of Set 9 | kysyl-syr
# City not found.Skipping...
# Processig Record 4 of Set 9 | chernyshevskiy
# Processig Record 5 of Set 9 | medicine hat
# Processig Record 6 of Set 9 | bathsheba
# Processig Record 7 of Set 9 | mehamn
# Processig Record 8 of Set 9 | kamaishi
# Processig Record 9 of Set 9 | sambava
# Processig Record 10 of Set 9 | kidal
# Processig Record 11 of Set 9 | jerecuaro
# Processig Record 12 of Set 9 | guanica
# Processig Record 13 of Set 9 | koubia
# Processig Record 14 of Set 9 | hualmay
# Processig Record 15 of Set 9 | chupa
# Processig Record 16 of Set 9 | bichura
# Processig Record 17 of Set 9 | hohhot
# Processig Record 18 of Set 9 | sembakung
# Processig Record 19 of Set 9 | okahandja
# Processig Record 20 of Set 9 | aswan
# Processig Record 21 of Set 9 | srivardhan
# Processig Record 22 of Set 9 | australind
# Processig Record 23 of Set 9 | boa esperanca do sul
# Processig Record 24 of Set 9 | beruwala
# Processig Record 25 of Set 9 | babylon
# City not found.Skipping...
# Processig Record 27 of Set 9 | santa rosa
# City not found.Skipping...
# Processig Record 29 of Set 9 | quatre cocos
# Processig Record 30 of Set 9 | bure
# Processig Record 31 of Set 9 | pemangkat
# Processig Record 32 of Set 9 | anloga
# Processig Record 33 of Set 9 | the valley
# City not found.Skipping...
# Processig Record 35 of Set 9 | nanjing
# Processig Record 36 of Set 9 | naze
# Processig Record 37 of Set 9 | nome
# Processig Record 38 of Set 9 | porto recanati
# Processig Record 39 of Set 9 | matara
# Processig Record 40 of Set 9 | opatija
# Processig Record 41 of Set 9 | alyangula
# Processig Record 42 of Set 9 | presidencia roque saenz pena
# Processig Record 43 of Set 9 | poso
# Processig Record 44 of Set 9 | hovd
# Processig Record 45 of Set 9 | asosa
# Processig Record 46 of Set 9 | tabriz
# Processig Record 47 of Set 9 | kudahuvadhoo
# Processig Record 48 of Set 9 | namatanai
# Processig Record 49 of Set 9 | mpwapwa
# Processig Record 50 of Set 9 | saint-leu
# Processig Record 1 of Set 10 | ayan
# Processig Record 2 of Set 10 | ossora
# Processig Record 3 of Set 10 | crestview
# Processig Record 4 of Set 10 | minden
# Processig Record 5 of Set 10 | pangnirtung
# Processig Record 6 of Set 10 | muli
# Processig Record 7 of Set 10 | dingle
# Processig Record 8 of Set 10 | sorland
# Processig Record 9 of Set 10 | preeceville
# Processig Record 10 of Set 10 | makarov
# City not found.Skipping...
# Processig Record 12 of Set 10 | lucea
# Processig Record 13 of Set 10 | shubarshi
# City not found.Skipping...
# City not found.Skipping...
# Processig Record 16 of Set 10 | santa ines
# Processig Record 17 of Set 10 | ahipara
# Processig Record 18 of Set 10 | villa carlos paz
# Processig Record 19 of Set 10 | inyonga
# Processig Record 20 of Set 10 | marzuq
# Processig Record 21 of Set 10 | moba
# Processig Record 22 of Set 10 | grindavik
# Processig Record 23 of Set 10 | whitehorse
# City not found.Skipping...
# Processig Record 25 of Set 10 | mitsamiouli
# Processig Record 26 of Set 10 | petra
# Processig Record 27 of Set 10 | juneau
# Processig Record 28 of Set 10 | valentin gomez farias
# Processig Record 29 of Set 10 | torbay
# Processig Record 30 of Set 10 | elk
# Processig Record 31 of Set 10 | spring valley
# Processig Record 32 of Set 10 | tucuman
# Processig Record 33 of Set 10 | udachnyy
# Processig Record 34 of Set 10 | berlevag
# Processig Record 35 of Set 10 | sao felix do xingu
# Processig Record 36 of Set 10 | presque isle
# Processig Record 37 of Set 10 | chara
# Processig Record 38 of Set 10 | palm valley
# Processig Record 39 of Set 10 | ambulu
# Processig Record 40 of Set 10 | kuhdasht
# Processig Record 41 of Set 10 | itaituba
# Processig Record 42 of Set 10 | benguela
# Processig Record 43 of Set 10 | teguldet
# Processig Record 44 of Set 10 | taoudenni
# Processig Record 45 of Set 10 | bhitarwar
# Processig Record 46 of Set 10 | shache
# Processig Record 47 of Set 10 | eirunepe
# Processig Record 48 of Set 10 | bilma
# Processig Record 49 of Set 10 | mahebourg
# Processig Record 50 of Set 10 | iwanai
# Processig Record 1 of Set 11 | tautira
# Processig Record 2 of Set 11 | lufilufi
# Processig Record 3 of Set 11 | filadelfia
# Processig Record 4 of Set 11 | port macquarie
# City not found.Skipping...
# Processig Record 6 of Set 11 | ballina
# Processig Record 7 of Set 11 | otradnoye
# Processig Record 8 of Set 11 | kadoma
# Processig Record 9 of Set 11 | roald
# Processig Record 10 of Set 11 | catabola
# Processig Record 11 of Set 11 | okhotsk
# Processig Record 12 of Set 11 | forestville
# City not found.Skipping...
# City not found.Skipping...
# Processig Record 15 of Set 11 | high level
# Processig Record 16 of Set 11 | bara
# Processig Record 17 of Set 11 | rocha
# Processig Record 18 of Set 11 | bandarbeyla
# Processig Record 19 of Set 11 | olinda
# Processig Record 20 of Set 11 | noumea
# City not found.Skipping...
# Processig Record 22 of Set 11 | fernley
# Processig Record 23 of Set 11 | revda
# Processig Record 24 of Set 11 | iowa city
# Processig Record 25 of Set 11 | jingdezhen
# City not found.Skipping...
# Processig Record 27 of Set 11 | bodden town
# Processig Record 28 of Set 11 | donskoye
# Processig Record 29 of Set 11 | aloleng
# Processig Record 30 of Set 11 | nikel
# Processig Record 31 of Set 11 | chimbote
# Processig Record 32 of Set 11 | geraldton
# Processig Record 33 of Set 11 | labrea
# Processig Record 34 of Set 11 | mount gambier
# Processig Record 35 of Set 11 | pangody
# Processig Record 36 of Set 11 | prado
# Processig Record 37 of Set 11 | shingu
# Processig Record 38 of Set 11 | baicheng
# Processig Record 39 of Set 11 | santa catarina de tepehuanes
# Processig Record 40 of Set 11 | isangel
# Processig Record 41 of Set 11 | macia
# Processig Record 42 of Set 11 | mezen
# Processig Record 43 of Set 11 | aras
# Processig Record 44 of Set 11 | kangaatsiaq
# Processig Record 45 of Set 11 | calvinia
# Processig Record 46 of Set 11 | xuddur
# Processig Record 47 of Set 11 | villazon
# Processig Record 48 of Set 11 | chandur
# City not found.Skipping...
# Processig Record 50 of Set 11 | igarka
# Processig Record 1 of Set 12 | lokossa
# Processig Record 2 of Set 12 | uchiza
# Processig Record 3 of Set 12 | bagotville
# Processig Record 4 of Set 12 | viedma
# Processig Record 5 of Set 12 | kirando
# Processig Record 6 of Set 12 | palu
# Processig Record 7 of Set 12 | kavieng
# Processig Record 8 of Set 12 | sungai padi
# Processig Record 9 of Set 12 | baykit
# Processig Record 10 of Set 12 | pacific grove
# Processig Record 11 of Set 12 | siocon
# Processig Record 12 of Set 12 | port-gentil
# Processig Record 13 of Set 12 | enumclaw
# Processig Record 14 of Set 12 | hobyo
# Processig Record 15 of Set 12 | aitape
# Processig Record 16 of Set 12 | marsh harbour
# Processig Record 17 of Set 12 | yishui
# Processig Record 18 of Set 12 | karakol
# Processig Record 19 of Set 12 | bekhtery
# Processig Record 20 of Set 12 | castleford
# City not found.Skipping...
# Processig Record 22 of Set 12 | krasnokamensk
# Processig Record 23 of Set 12 | teguise
# Processig Record 24 of Set 12 | comodoro rivadavia
# Processig Record 25 of Set 12 | pithoragarh
# Processig Record 26 of Set 12 | vawkavysk
# Processig Record 27 of Set 12 | groningen
# Processig Record 28 of Set 12 | high rock
# Processig Record 29 of Set 12 | brae
# City not found.Skipping...
# Processig Record 31 of Set 12 | peachland
# Processig Record 32 of Set 12 | ypsonas
# Processig Record 33 of Set 12 | peleduy
# Processig Record 34 of Set 12 | hay river
# Processig Record 35 of Set 12 | cabinda
# Processig Record 36 of Set 12 | komsomolskiy
# Processig Record 37 of Set 12 | cocorit
# Processig Record 38 of Set 12 | ingham
# Processig Record 39 of Set 12 | esso
# Processig Record 40 of Set 12 | mancio lima
# Processig Record 41 of Set 12 | marsaxlokk
# Processig Record 42 of Set 12 | saldanha
# Processig Record 43 of Set 12 | mamallapuram
# Processig Record 44 of Set 12 | anadyr
# Processig Record 45 of Set 12 | pak chong
# Processig Record 46 of Set 12 | warrington
# Processig Record 47 of Set 12 | kaeo
# Processig Record 48 of Set 12 | marystown
# Processig Record 49 of Set 12 | kokoda
# Processig Record 50 of Set 12 | fallon
# --------------------------------------------------------
# ----------------End of Data Retrieval-------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# create a dictionary with weather data by city
city_data={"City": city,
         "Cloudiness": Cloudiness,
         "Country": Country,
         "Date": Date,
         "Humidity": Humidity,
         "Lat": Lat,
         "Lng": Lng,
         "Max_Temp": Max_temp,
         "Wind_Speed": Wind_speed,
        }
# create a dataframe from the city weather data dictionary
city_data_df = pd.DataFrame.from_dict(city_data)

# %%
city_data_df.head()
# Out:
#       City  Cloudiness Country        Date  Humidity      Lat      Lng  \
# 0  mazagao          96      RU  1639785713        99  59.7035  30.7861
# 1  mazagao          97      SO  1639785714        67   3.8093  43.2471
# 2  mazagao           0      LY  1639785714        53  27.0377  14.4283
# 3  mazagao          89      KZ  1639785715        86  48.8264  58.1442
# 4  mazagao          16      RE  1639785716        76 -21.3667  55.6167
#
#    Max_Temp  Wind_Speed
# 0    272.09        1.31
# 1    297.87        5.15
# 2    283.09        3.45
# 3    268.24        2.34
# 4    295.36        1.30

# %%
city_data_df.count()
# Out:
# City          552
# Cloudiness    552
# Country       552
# Date          552
# Humidity      552
# Lat           552
# Lng           552
# Max_Temp      552
# Wind_Speed    552
# dtype: int64

# %%
# export the city data to a csv file
city_data_df.to_csv('weather_cities.csv', encoding='utf-8')

# %%
# read CSV file and display dataframe

df = pd.read_csv('weather_cities.csv')
df.head()
# Out:
#    Unnamed: 0     City  Cloudiness Country        Date  Humidity      Lat  \
# 0           0  mazagao          96      RU  1639785713        99  59.7035
# 1           1  mazagao          97      SO  1639785714        67   3.8093
# 2           2  mazagao           0      LY  1639785714        53  27.0377
# 3           3  mazagao          89      KZ  1639785715        86  48.8264
# 4           4  mazagao          16      RE  1639785716        76 -21.3667
#
#        Lng  Max_Temp  Wind_Speed
# 0  30.7861    272.09        1.31
# 1  43.2471    297.87        5.15
# 2  14.4283    283.09        3.45
# 3  58.1442    268.24        2.34
# 4  55.6167    295.36        1.30

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
h_df = df.sort_values(["Humidity"], ascending=False)
h_df.head()
# Out:
#      Unnamed: 0     City  Cloudiness Country        Date  Humidity      Lat  \
# 325         325  mazagao          89      RU  1639786394       100  63.3667
# 246         246  mazagao          90      RU  1639786206       100  62.2248
# 370         370  mazagao          74      RU  1639786492       100  63.0128
# 252         252  mazagao          86      RU  1639786212       100  63.4453
# 348         348  mazagao          85      RU  1639786412       100  65.4410
#
#           Lng  Max_Temp  Wind_Speed
# 325   47.9167    251.34        1.14
# 246   49.9922    254.56        1.66
# 370  112.4714    228.57        0.81
# 252  120.3167    228.78        0.85
# 348   52.1498    253.29        1.61

# %%
humid_df=h_df.loc[h_df["Humidity"] > 100]
humid_df
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, City, Cloudiness, Country, Date, Humidity, Lat, Lng, Max_Temp, Wind_Speed]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.

#humid_df.set_index(['City', 'Humidity'])
humid_df.index.name = 'Index'
humid100_df = humid_df[['City', 'Humidity']]

humid100_df.head()
# Out:
# Empty DataFrame
# Columns: [City, Humidity]
# Index: []

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

clean_city_data=df.drop(df[df['Humidity'] < 100].index, inplace = False)
clean_city_data.head()
# Out:
#      Unnamed: 0     City  Cloudiness Country        Date  Humidity      Lat  \
# 325         325  mazagao          89      RU  1639786394       100  63.3667
# 370         370  mazagao          74      RU  1639786492       100  63.0128
# 432         432  mazagao          90      IS  1639786603       100  63.8424
# 211         211  mazagao          90      US  1639786118       100  35.6234
# 238         238  mazagao          90      RU  1639786199       100  71.9667
#
#           Lng  Max_Temp  Wind_Speed
# 325   47.9167    251.34        1.14
# 370  112.4714    228.57        0.81
# 432  -22.4338    277.41        3.60
# 211  -95.9605    286.81        5.66
# 238  102.5000    233.06        2.16

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
